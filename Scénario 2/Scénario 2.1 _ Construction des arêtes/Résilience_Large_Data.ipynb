# %% [markdown]
# # Scénario 2 - Panne sur le réseau de chaleur
# On souhaite améliorer la résilience de notre réseau en ajoutant des arêtes de secours qui serait utiliser qu'en cas de panne

# %%
"""
from google.colab import files
import os
import shutil

uploaded = files.upload()
dest_path = "/content/data/"
os.makedirs(os.path.dirname(dest_path), exist_ok=True)
shutil.move("/content/InputDataEnergyLargeInstance.xlsx", dest_path)
#shutil.move("/content/InputDataEnergySmallInstance.xlsx", dest_path)
shutil.rmtree("/content/sample_data/", ignore_errors=True, onerror=None)
"""
# Out:
# '\nfrom google.colab import files\nimport os\nimport shutil\n\nuploaded = files.upload()\ndest_path = "/content/data/"\nos.makedirs(os.path.dirname(dest_path), exist_ok=True)\nshutil.move("/content/InputDataEnergyLargeInstance.xlsx", dest_path)\n#shutil.move("/content/InputDataEnergySmallInstance.xlsx", dest_path)\nshutil.rmtree("/content/sample_data/", ignore_errors=True, onerror=None)\n'

# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.1.1)

# %%
# Import PuLP modeler functions
from pulp import *
import pandas as pd
import numpy as np

# %%
InputData = "/content/data/InputDataEnergyLargeInstance.xlsx"  # Large instance

# %%
# Input Data Preparation
def read_excel_data(filename, sheet_name):
  data = pd.read_excel(filename, sheet_name=sheet_name, header=None)
  values = data.values
  if min(values.shape) == 1:  # This If is to make the code insensitive to column-wise or row-wise expression
      if values.shape[0] == 1:
          values = values.tolist()
      else:
          values = values.transpose()
          values = values.tolist()
      return values[0]
  else:
      data_dict = {}
      if min(values.shape) == 2:  # For single-dimension parameters in Excel
          if values.shape[0] == 2:
              for i in range(values.shape[1]):
                  data_dict[i] = values[1][i]
          else:
              for i in range(values.shape[0]):
                  data_dict[i] = (values[i][0],values[i][1])

      else:  # For two-dimension (matrix) parameters in Excel
          for i in range(values.shape[0]):
              for j in range(values.shape[1]):
                  data_dict[(i, j)] = values[i][j]
      return data_dict

# %%
#parameters
NodesCord = read_excel_data(InputData, "NodesCord")
Nodes = read_excel_data(InputData, "Nodes")
V = [i for i in range(0,Nodes[0])]
E = [(i, j) for i in range(0, Nodes[0] ) for j in range(0, Nodes[0] )]
l={}
for i in range(Nodes[0]):
    for j in range(Nodes[0]):
        l[(i,j)]=((NodesCord[i][0]-NodesCord[j][0])**2+(NodesCord[i][1]-NodesCord[j][1])**2)**(1/2)

V0 = read_excel_data(InputData, "SourceNum")
for i in range(len(V0)):
  V0[i]=V0[i]-1
FixedUnitCost = read_excel_data(InputData, "FixedUnitCost")
vfix_thetaijfix = read_excel_data(InputData, "vfix(thetaijfix)")
vvar_thetaijvar = read_excel_data(InputData, "vvar(thetaijvar)")
cvar_cijvar = read_excel_data(InputData, "cvar(cijvar)")
cheat_ciheat = read_excel_data(InputData, "cheat(ciheat)")
com_cijom = read_excel_data(InputData, "com(cijom)")
crev_cijrev = read_excel_data(InputData, "crev(cijrev)")
Tflh_Tiflh = read_excel_data(InputData, "Tflh(Tiflh)")
Betta = read_excel_data(InputData, "Betta")
Lambda = read_excel_data(InputData, "Lambda")
Alpha = read_excel_data(InputData, "Alpha")
EdgesDemandPeak_dij = read_excel_data(InputData, "EdgesDemandPeak(dij)")
EdgesDemandAnnual_dij =  read_excel_data(InputData, "EdgesDemandAnnual(Dij)")
Cmax_cijmax = read_excel_data(InputData, "Cmax(cijmax)")
SourceMaxCap_Qimax = read_excel_data(InputData, "SourceMaxCap(Qimax)")
pumd_pijumd = read_excel_data(InputData, "pumd(pijumd)")

# %%
#decision variables
X=LpVariable.dicts("X",(V,V),lowBound=0,upBound=1,cat="Binary")
P_Out=LpVariable.dicts("P_Out",(V,V),lowBound=0,upBound=None,cat="Continuous")
P_In=LpVariable.dicts("P_In",(V,V),lowBound=0,upBound=None,cat="Continuous")
problem=LpProblem("problem",LpMinimize)

# %%
# Constraint 1
"""sum_x =[]
for i in range(len(V)):
  for j in range(len(V)):
    sum_x.append(X[i][j])"""
problem += lpSum([X[i][j] for i in range(len(V)) for j in range(len(V))]) == len(V) - 1

# Constraint 2
for i in range(len(V)):
    for j in range(i+1,len(V)):
        problem += lpSum([X[i][j],X[j][i]]) <= 1

# Constraint 3
for (i,j) in E:
    eta = 1 - vvar_thetaijvar[(i,j)]*l[(i,j)]
    delta = EdgesDemandPeak_dij[(i,j)]*Betta[0]*Lambda[0] + l[(i,j)]*vfix_thetaijfix[(i,j)]
    problem += lpSum([eta*P_In[i][j],-P_Out[i][j],-delta*X[i][j]]) == 0

# Constraint 4
"""for j in range(4,len(V)):
    sum_out_in= []
    for i in range(len(V)):
        if i != j:
            sum_out_in.append(P_Out[i][j])
            sum_out_in.append(-P_In[j][i])
            problem +=lpSum(sum_out_in) == 0"""
for j in range(0,len(V)):
  if j not in V0:
    problem += lpSum(P_Out[i][j]-P_In[j][i] for i in range(len(V)) if i != j) == 0

# Constraint 5
for i in range(len(V)):
  for j in range(len(V)):
    problem += lpSum([P_In[i][j],-X[i][j]*Cmax_cijmax[(i,j)] ]) <= 0

# Constraint 6
for v in V0:
  for i in range(len(V)):
    if i != v:
      problem += X[i][v] == 0
      problem += P_In[i][v] == 0
"""problem += sum_X == 0"""

# Constraint 7
for v in V0:
  sum_PIN =[]
  for i in range(len(V)):
      if i != v:
          sum_PIN.append(P_In[v][i])
  problem += lpSum(sum_PIN) <= SourceMaxCap_Qimax[0]

# Constraint 8
for i in range(0,len(V)):
  if i not in V0:
    summ=[]
    for j in range(len(V)):
        if j!=i:
          summ.append(X[j][i])
    problem += lpSum(summ) >= 1

# Constraint 9
for i in range(len(V)):
  for j in range(len(V)):
    problem += P_In[i][j] >= 0
    problem += P_Out[i][j] >= 0
    problem += X[i][j] >= 0
    problem += X[i][j] <= 1

# %%
#objective function
n=len(V)

#revenue
revenue=0
for i in range(n):
  for j in range(n):
    revenue+=crev_cijrev[(i,j)]*EdgesDemandAnnual_dij[(i,j)]*Lambda[0]*X[i][j]

#Heat generation
heat_generation=0
for j in range(n):
  for v in V0:
    heat_generation+=P_In[v][j]*Tflh_Tiflh[0]*cheat_ciheat[v]
heat_generation=(1/Betta[0])*heat_generation

#maintenance
maintenance=0
for i in range(n):
  for j in range(n):
    maintenance+=com_cijom[(i,j)]*l[(i,j)]*X[i][j]

#total fixed investment cost
total_fixed_investment_cost=0
for i in range(Nodes[0]):
    for j in range(Nodes[0]):
        total_fixed_investment_cost+=l[(i,j)]*FixedUnitCost[0]*X[i][j]*Alpha[0]

#total variable investment cost
total_var=0
for i in range(n):
  for j in range(n):
    total_var+=cvar_cijvar[(i,j)]*P_In[i][j]*l[(i,j)]*Alpha[0]

#unmet demand
unmet_demand=0
for i in range(n):
  for j in range(i+1,n):
    unmet_demand+=lpSum([1,-X[i][j],-X[j][i]])*pumd_pijumd[(i,j)]*EdgesDemandAnnual_dij[(i,j)]

#objective function
objective_function=-(revenue-heat_generation-maintenance-total_fixed_investment_cost-total_var-unmet_demand)
problem+=objective_function
problem.solve()
LpStatus[problem.status]
# Out:
# 'Optimal'

# %%
for v in problem.variables():
  print(v.name,"=",v.varValue)
print("objective_function","=",value(problem.objective))
# Out:
# P_In_0_0 = 0.0
# P_In_0_1 = 0.0
# P_In_0_10 = 0.0
# P_In_0_11 = 0.0
# P_In_0_12 = 0.0
# P_In_0_13 = 0.0
# P_In_0_14 = 0.0
# P_In_0_15 = 0.0
# P_In_0_16 = 0.0
# P_In_0_17 = 0.0
# P_In_0_18 = 0.0
# P_In_0_19 = 0.0
# P_In_0_2 = 0.0
# P_In_0_20 = 0.0
# P_In_0_21 = 0.0
# P_In_0_22 = 0.0
# P_In_0_23 = 0.0
# P_In_0_24 = 0.0
# P_In_0_25 = 803.49357
# P_In_0_26 = 0.0
# P_In_0_27 = 0.0
# P_In_0_28 = 0.0
# P_In_0_29 = 0.0
# P_In_0_3 = 0.0
# P_In_0_4 = 0.0
# P_In_0_5 = 0.0
# P_In_0_6 = 0.0
# P_In_0_7 = 0.0
# P_In_0_8 = 0.0
# P_In_0_9 = 0.0
# P_In_10_0 = 0.0
# P_In_10_1 = 0.0
# P_In_10_10 = 0.0
# P_In_10_11 = 0.0
# P_In_10_12 = 0.0
# P_In_10_13 = 0.0
# P_In_10_14 = 0.0
# P_In_10_15 = 0.0
# P_In_10_16 = 0.0
# P_In_10_17 = 0.0
# P_In_10_18 = 0.0
# P_In_10_19 = 0.0
# P_In_10_2 = 0.0
# P_In_10_20 = 0.0
# P_In_10_21 = 0.0
# P_In_10_22 = 0.0
# P_In_10_23 = 0.0
# P_In_10_24 = 0.0
# P_In_10_25 = 0.0
# P_In_10_26 = 0.0
# P_In_10_27 = 0.0
# P_In_10_28 = 0.0
# P_In_10_29 = 0.0
# P_In_10_3 = 0.0
# P_In_10_4 = 0.0
# P_In_10_5 = 0.0
# P_In_10_6 = 0.0
# P_In_10_7 = 926.74228
# P_In_10_8 = 0.0
# P_In_10_9 = 0.0
# P_In_11_0 = 0.0
# P_In_11_1 = 0.0
# P_In_11_10 = 0.0
# P_In_11_11 = 0.0
# P_In_11_12 = 0.0
# P_In_11_13 = 0.0
# P_In_11_14 = 0.0
# P_In_11_15 = 0.0
# P_In_11_16 = 0.0
# P_In_11_17 = 0.0
# P_In_11_18 = 0.0
# P_In_11_19 = 0.0
# P_In_11_2 = 0.0
# P_In_11_20 = 0.0
# P_In_11_21 = 0.0
# P_In_11_22 = 0.0
# P_In_11_23 = 0.0
# P_In_11_24 = 0.0
# P_In_11_25 = 0.0
# P_In_11_26 = 0.0
# P_In_11_27 = 0.0
# P_In_11_28 = 0.0
# P_In_11_29 = 121.22882
# P_In_11_3 = 0.0
# P_In_11_4 = 0.0
# P_In_11_5 = 0.0
# P_In_11_6 = 0.0
# P_In_11_7 = 0.0
# P_In_11_8 = 0.0
# P_In_11_9 = 0.0
# P_In_12_0 = 0.0
# P_In_12_1 = 0.0
# P_In_12_10 = 0.0
# P_In_12_11 = 655.58933
# P_In_12_12 = 0.0
# P_In_12_13 = 0.0
# P_In_12_14 = 0.0
# P_In_12_15 = 0.0
# P_In_12_16 = 0.0
# P_In_12_17 = 0.0
# P_In_12_18 = 0.0
# P_In_12_19 = 0.0
# P_In_12_2 = 0.0
# P_In_12_20 = 0.0
# P_In_12_21 = 0.0
# P_In_12_22 = 0.0
# P_In_12_23 = 0.0
# P_In_12_24 = 0.0
# P_In_12_25 = 0.0
# P_In_12_26 = 0.0
# P_In_12_27 = 0.0
# P_In_12_28 = 0.0
# P_In_12_29 = 0.0
# P_In_12_3 = 0.0
# P_In_12_4 = 0.0
# P_In_12_5 = 0.0
# P_In_12_6 = 0.0
# P_In_12_7 = 0.0
# P_In_12_8 = 0.0
# P_In_12_9 = 0.0
# P_In_13_0 = 0.0
# P_In_13_1 = 0.0
# P_In_13_10 = 0.0
# P_In_13_11 = 0.0
# P_In_13_12 = 0.0
# P_In_13_13 = 0.0
# P_In_13_14 = 0.0
# P_In_13_15 = 0.0
# P_In_13_16 = 0.0
# P_In_13_17 = 0.0
# P_In_13_18 = 0.0
# P_In_13_19 = 0.0
# P_In_13_2 = 0.0
# P_In_13_20 = 0.0
# P_In_13_21 = 0.0
# P_In_13_22 = 0.0
# P_In_13_23 = 504.93458
# P_In_13_24 = 0.0
# P_In_13_25 = 0.0
# P_In_13_26 = 0.0
# P_In_13_27 = 0.0
# P_In_13_28 = 0.0
# P_In_13_29 = 0.0
# P_In_13_3 = 0.0
# P_In_13_4 = 0.0
# P_In_13_5 = 0.0
# P_In_13_6 = 0.0
# P_In_13_7 = 0.0
# P_In_13_8 = 0.0
# P_In_13_9 = 0.0
# P_In_14_0 = 0.0
# P_In_14_1 = 0.0
# P_In_14_10 = 0.0
# P_In_14_11 = 0.0
# P_In_14_12 = 0.0
# P_In_14_13 = 0.0
# P_In_14_14 = 0.0
# P_In_14_15 = 0.0
# P_In_14_16 = 0.0
# P_In_14_17 = 0.0
# P_In_14_18 = 0.0
# P_In_14_19 = 0.0
# P_In_14_2 = 0.0
# P_In_14_20 = 0.0
# P_In_14_21 = 0.0
# P_In_14_22 = 0.0
# P_In_14_23 = 0.0
# P_In_14_24 = 0.0
# P_In_14_25 = 0.0
# P_In_14_26 = 0.0
# P_In_14_27 = 0.0
# P_In_14_28 = 0.0
# P_In_14_29 = 0.0
# P_In_14_3 = 0.0
# P_In_14_4 = 0.0
# P_In_14_5 = 0.0
# P_In_14_6 = 0.0
# P_In_14_7 = 0.0
# P_In_14_8 = 0.0
# P_In_14_9 = 0.0
# P_In_15_0 = 0.0
# P_In_15_1 = 0.0
# P_In_15_10 = 0.0
# P_In_15_11 = 0.0
# P_In_15_12 = 0.0
# P_In_15_13 = 0.0
# P_In_15_14 = 0.0
# P_In_15_15 = 0.0
# P_In_15_16 = 0.0
# P_In_15_17 = 0.0
# P_In_15_18 = 0.0
# P_In_15_19 = 0.0
# P_In_15_2 = 0.0
# P_In_15_20 = 0.0
# P_In_15_21 = 0.0
# P_In_15_22 = 0.0
# P_In_15_23 = 0.0
# P_In_15_24 = 0.0
# P_In_15_25 = 0.0
# P_In_15_26 = 0.0
# P_In_15_27 = 0.0
# P_In_15_28 = 0.0
# P_In_15_29 = 0.0
# P_In_15_3 = 0.0
# P_In_15_4 = 0.0
# P_In_15_5 = 0.0
# P_In_15_6 = 0.0
# P_In_15_7 = 0.0
# P_In_15_8 = 0.0
# P_In_15_9 = 0.0
# P_In_16_0 = 0.0
# P_In_16_1 = 0.0
# P_In_16_10 = 0.0
# P_In_16_11 = 0.0
# P_In_16_12 = 0.0
# P_In_16_13 = 0.0
# P_In_16_14 = 0.0
# P_In_16_15 = 0.0
# P_In_16_16 = 0.0
# P_In_16_17 = 0.0
# P_In_16_18 = 0.0
# P_In_16_19 = 0.0
# P_In_16_2 = 0.0
# P_In_16_20 = 0.0
# P_In_16_21 = 0.0
# P_In_16_22 = 0.0
# P_In_16_23 = 0.0
# P_In_16_24 = 0.0
# P_In_16_25 = 0.0
# P_In_16_26 = 0.0
# P_In_16_27 = 0.0
# P_In_16_28 = 0.0
# P_In_16_29 = 0.0
# P_In_16_3 = 0.0
# P_In_16_4 = 0.0
# P_In_16_5 = 0.0
# P_In_16_6 = 0.0
# P_In_16_7 = 0.0
# P_In_16_8 = 0.0
# P_In_16_9 = 0.0
# P_In_17_0 = 0.0
# P_In_17_1 = 0.0
# P_In_17_10 = 0.0
# P_In_17_11 = 0.0
# P_In_17_12 = 1069.7446
# P_In_17_13 = 0.0
# P_In_17_14 = 0.0
# P_In_17_15 = 0.0
# P_In_17_16 = 0.0
# P_In_17_17 = 0.0
# P_In_17_18 = 0.0
# P_In_17_19 = 0.0
# P_In_17_2 = 0.0
# P_In_17_20 = 0.0
# P_In_17_21 = 0.0
# P_In_17_22 = 0.0
# P_In_17_23 = 0.0
# P_In_17_24 = 0.0
# P_In_17_25 = 0.0
# P_In_17_26 = 0.0
# P_In_17_27 = 0.0
# P_In_17_28 = 0.0
# P_In_17_29 = 0.0
# P_In_17_3 = 0.0
# P_In_17_4 = 0.0
# P_In_17_5 = 0.0
# P_In_17_6 = 0.0
# P_In_17_7 = 0.0
# P_In_17_8 = 0.0
# P_In_17_9 = 0.0
# P_In_18_0 = 0.0
# P_In_18_1 = 2796.6175
# P_In_18_10 = 0.0
# P_In_18_11 = 0.0
# P_In_18_12 = 0.0
# P_In_18_13 = 0.0
# P_In_18_14 = 0.0
# P_In_18_15 = 0.0
# P_In_18_16 = 0.0
# P_In_18_17 = 0.0
# P_In_18_18 = 0.0
# P_In_18_19 = 0.0
# P_In_18_2 = 0.0
# P_In_18_20 = 0.0
# P_In_18_21 = 0.0
# P_In_18_22 = 0.0
# P_In_18_23 = 0.0
# P_In_18_24 = 0.0
# P_In_18_25 = 0.0
# P_In_18_26 = 0.0
# P_In_18_27 = 0.0
# P_In_18_28 = 0.0
# P_In_18_29 = 0.0
# P_In_18_3 = 0.0
# P_In_18_4 = 0.0
# P_In_18_5 = 0.0
# P_In_18_6 = 0.0
# P_In_18_7 = 0.0
# P_In_18_8 = 0.0
# P_In_18_9 = 0.0
# P_In_19_0 = 0.0
# P_In_19_1 = 0.0
# P_In_19_10 = 0.0
# P_In_19_11 = 0.0
# P_In_19_12 = 0.0
# P_In_19_13 = 0.0
# P_In_19_14 = 0.0
# P_In_19_15 = 0.0
# P_In_19_16 = 0.0
# P_In_19_17 = 0.0
# P_In_19_18 = 2994.5119
# P_In_19_19 = 0.0
# P_In_19_2 = 0.0
# P_In_19_20 = 0.0
# P_In_19_21 = 4670.2786
# P_In_19_22 = 0.0
# P_In_19_23 = 0.0
# P_In_19_24 = 0.0
# P_In_19_25 = 0.0
# P_In_19_26 = 0.0
# P_In_19_27 = 0.0
# P_In_19_28 = 0.0
# P_In_19_29 = 0.0
# P_In_19_3 = 0.0
# P_In_19_4 = 0.0
# P_In_19_5 = 0.0
# P_In_19_6 = 0.0
# P_In_19_7 = 0.0
# P_In_19_8 = 0.0
# P_In_19_9 = 0.0
# P_In_1_0 = 0.0
# P_In_1_1 = 0.0
# P_In_1_10 = 0.0
# P_In_1_11 = 0.0
# P_In_1_12 = 0.0
# P_In_1_13 = 0.0
# P_In_1_14 = 0.0
# P_In_1_15 = 0.0
# P_In_1_16 = 296.61819
# P_In_1_17 = 0.0
# P_In_1_18 = 0.0
# P_In_1_19 = 0.0
# P_In_1_2 = 0.0
# P_In_1_20 = 1990.8547
# P_In_1_21 = 0.0
# P_In_1_22 = 0.0
# P_In_1_23 = 0.0
# P_In_1_24 = 0.0
# P_In_1_25 = 0.0
# P_In_1_26 = 0.0
# P_In_1_27 = 0.0
# P_In_1_28 = 0.0
# P_In_1_29 = 0.0
# P_In_1_3 = 0.0
# P_In_1_4 = 0.0
# P_In_1_5 = 0.0
# P_In_1_6 = 0.0
# P_In_1_7 = 0.0
# P_In_1_8 = 0.0
# P_In_1_9 = 0.0
# P_In_20_0 = 0.0
# P_In_20_1 = 0.0
# P_In_20_10 = 0.0
# P_In_20_11 = 0.0
# P_In_20_12 = 0.0
# P_In_20_13 = 0.0
# P_In_20_14 = 0.0
# P_In_20_15 = 0.0
# P_In_20_16 = 0.0
# P_In_20_17 = 1606.3178
# P_In_20_18 = 0.0
# P_In_20_19 = 0.0
# P_In_20_2 = 0.0
# P_In_20_20 = 0.0
# P_In_20_21 = 0.0
# P_In_20_22 = 0.0
# P_In_20_23 = 0.0
# P_In_20_24 = 0.0
# P_In_20_25 = 0.0
# P_In_20_26 = 0.0
# P_In_20_27 = 0.0
# P_In_20_28 = 0.0
# P_In_20_29 = 0.0
# P_In_20_3 = 0.0
# P_In_20_4 = 0.0
# P_In_20_5 = 0.0
# P_In_20_6 = 0.0
# P_In_20_7 = 0.0
# P_In_20_8 = 0.0
# P_In_20_9 = 0.0
# P_In_21_0 = 0.0
# P_In_21_1 = 0.0
# P_In_21_10 = 0.0
# P_In_21_11 = 0.0
# P_In_21_12 = 0.0
# P_In_21_13 = 0.0
# P_In_21_14 = 0.0
# P_In_21_15 = 0.0
# P_In_21_16 = 0.0
# P_In_21_17 = 0.0
# P_In_21_18 = 0.0
# P_In_21_19 = 0.0
# P_In_21_2 = 0.0
# P_In_21_20 = 0.0
# P_In_21_21 = 0.0
# P_In_21_22 = 0.0
# P_In_21_23 = 0.0
# P_In_21_24 = 0.0
# P_In_21_25 = 0.0
# P_In_21_26 = 0.0
# P_In_21_27 = 0.0
# P_In_21_28 = 0.0
# P_In_21_29 = 0.0
# P_In_21_3 = 0.0
# P_In_21_4 = 2070.1933
# P_In_21_5 = 0.0
# P_In_21_6 = 1959.2436
# P_In_21_7 = 0.0
# P_In_21_8 = 0.0
# P_In_21_9 = 0.0
# P_In_22_0 = 0.0
# P_In_22_1 = 0.0
# P_In_22_10 = 0.0
# P_In_22_11 = 0.0
# P_In_22_12 = 0.0
# P_In_22_13 = 0.0
# P_In_22_14 = 0.0
# P_In_22_15 = 0.0
# P_In_22_16 = 0.0
# P_In_22_17 = 0.0
# P_In_22_18 = 0.0
# P_In_22_19 = 0.0
# P_In_22_2 = 0.0
# P_In_22_20 = 0.0
# P_In_22_21 = 0.0
# P_In_22_22 = 0.0
# P_In_22_23 = 0.0
# P_In_22_24 = 139.63932
# P_In_22_25 = 0.0
# P_In_22_26 = 0.0
# P_In_22_27 = 0.0
# P_In_22_28 = 0.0
# P_In_22_29 = 0.0
# P_In_22_3 = 0.0
# P_In_22_4 = 0.0
# P_In_22_5 = 0.0
# P_In_22_6 = 0.0
# P_In_22_7 = 0.0
# P_In_22_8 = 0.0
# P_In_22_9 = 0.0
# P_In_23_0 = 0.0
# P_In_23_1 = 0.0
# P_In_23_10 = 0.0
# P_In_23_11 = 0.0
# P_In_23_12 = 0.0
# P_In_23_13 = 0.0
# P_In_23_14 = 0.0
# P_In_23_15 = 0.0
# P_In_23_16 = 0.0
# P_In_23_17 = 0.0
# P_In_23_18 = 0.0
# P_In_23_19 = 0.0
# P_In_23_2 = 0.0
# P_In_23_20 = 0.0
# P_In_23_21 = 0.0
# P_In_23_22 = 0.0
# P_In_23_23 = 0.0
# P_In_23_24 = 0.0
# P_In_23_25 = 0.0
# P_In_23_26 = 374.59924
# P_In_23_27 = 0.0
# P_In_23_28 = 0.0
# P_In_23_29 = 0.0
# P_In_23_3 = 0.0
# P_In_23_4 = 0.0
# P_In_23_5 = 0.0
# P_In_23_6 = 0.0
# P_In_23_7 = 0.0
# P_In_23_8 = 0.0
# P_In_23_9 = 0.0
# P_In_24_0 = 0.0
# P_In_24_1 = 0.0
# P_In_24_10 = 0.0
# P_In_24_11 = 0.0
# P_In_24_12 = 0.0
# P_In_24_13 = 0.0
# P_In_24_14 = 0.0
# P_In_24_15 = 0.0
# P_In_24_16 = 0.0
# P_In_24_17 = 0.0
# P_In_24_18 = 0.0
# P_In_24_19 = 0.0
# P_In_24_2 = 0.0
# P_In_24_20 = 0.0
# P_In_24_21 = 0.0
# P_In_24_22 = 0.0
# P_In_24_23 = 0.0
# P_In_24_24 = 0.0
# P_In_24_25 = 0.0
# P_In_24_26 = 0.0
# P_In_24_27 = 0.0
# P_In_24_28 = 0.0
# P_In_24_29 = 0.0
# P_In_24_3 = 0.0
# P_In_24_4 = 0.0
# P_In_24_5 = 0.0
# P_In_24_6 = 0.0
# P_In_24_7 = 0.0
# P_In_24_8 = 0.0
# P_In_24_9 = 0.0
# P_In_25_0 = 0.0
# P_In_25_1 = 0.0
# P_In_25_10 = 0.0
# P_In_25_11 = 0.0
# P_In_25_12 = 0.0
# P_In_25_13 = 0.0
# P_In_25_14 = 0.0
# P_In_25_15 = 0.0
# P_In_25_16 = 0.0
# P_In_25_17 = 0.0
# P_In_25_18 = 0.0
# P_In_25_19 = 0.0
# P_In_25_2 = 0.0
# P_In_25_20 = 0.0
# P_In_25_21 = 0.0
# P_In_25_22 = 0.0
# P_In_25_23 = 0.0
# P_In_25_24 = 0.0
# P_In_25_25 = 0.0
# P_In_25_26 = 0.0
# P_In_25_27 = 439.90875
# P_In_25_28 = 0.0
# P_In_25_29 = 0.0
# P_In_25_3 = 0.0
# P_In_25_4 = 0.0
# P_In_25_5 = 0.0
# P_In_25_6 = 0.0
# P_In_25_7 = 0.0
# P_In_25_8 = 0.0
# P_In_25_9 = 0.0
# P_In_26_0 = 0.0
# P_In_26_1 = 0.0
# P_In_26_10 = 0.0
# P_In_26_11 = 0.0
# P_In_26_12 = 0.0
# P_In_26_13 = 0.0
# P_In_26_14 = 0.0
# P_In_26_15 = 90.309604
# P_In_26_16 = 0.0
# P_In_26_17 = 0.0
# P_In_26_18 = 0.0
# P_In_26_19 = 0.0
# P_In_26_2 = 0.0
# P_In_26_20 = 0.0
# P_In_26_21 = 0.0
# P_In_26_22 = 0.0
# P_In_26_23 = 0.0
# P_In_26_24 = 0.0
# P_In_26_25 = 0.0
# P_In_26_26 = 0.0
# P_In_26_27 = 0.0
# P_In_26_28 = 0.0
# P_In_26_29 = 0.0
# P_In_26_3 = 0.0
# P_In_26_4 = 0.0
# P_In_26_5 = 0.0
# P_In_26_6 = 0.0
# P_In_26_7 = 0.0
# P_In_26_8 = 0.0
# P_In_26_9 = 0.0
# P_In_27_0 = 0.0
# P_In_27_1 = 0.0
# P_In_27_10 = 0.0
# P_In_27_11 = 0.0
# P_In_27_12 = 0.0
# P_In_27_13 = 0.0
# P_In_27_14 = 0.0
# P_In_27_15 = 0.0
# P_In_27_16 = 0.0
# P_In_27_17 = 0.0
# P_In_27_18 = 0.0
# P_In_27_19 = 0.0
# P_In_27_2 = 0.0
# P_In_27_20 = 0.0
# P_In_27_21 = 0.0
# P_In_27_22 = 0.0
# P_In_27_23 = 0.0
# P_In_27_24 = 0.0
# P_In_27_25 = 0.0
# P_In_27_26 = 0.0
# P_In_27_27 = 0.0
# P_In_27_28 = 0.0
# P_In_27_29 = 0.0
# P_In_27_3 = 0.0
# P_In_27_4 = 0.0
# P_In_27_5 = 0.0
# P_In_27_6 = 0.0
# P_In_27_7 = 0.0
# P_In_27_8 = 0.0
# P_In_27_9 = 0.0
# P_In_28_0 = 0.0
# P_In_28_1 = 0.0
# P_In_28_10 = 0.0
# P_In_28_11 = 0.0
# P_In_28_12 = 0.0
# P_In_28_13 = 692.55936
# P_In_28_14 = 0.0
# P_In_28_15 = 0.0
# P_In_28_16 = 0.0
# P_In_28_17 = 0.0
# P_In_28_18 = 0.0
# P_In_28_19 = 0.0
# P_In_28_2 = 0.0
# P_In_28_20 = 0.0
# P_In_28_21 = 0.0
# P_In_28_22 = 0.0
# P_In_28_23 = 0.0
# P_In_28_24 = 0.0
# P_In_28_25 = 0.0
# P_In_28_26 = 0.0
# P_In_28_27 = 0.0
# P_In_28_28 = 0.0
# P_In_28_29 = 0.0
# P_In_28_3 = 0.0
# P_In_28_4 = 0.0
# P_In_28_5 = 0.0
# P_In_28_6 = 0.0
# P_In_28_7 = 0.0
# P_In_28_8 = 0.0
# P_In_28_9 = 0.0
# P_In_29_0 = 0.0
# P_In_29_1 = 0.0
# P_In_29_10 = 0.0
# P_In_29_11 = 0.0
# P_In_29_12 = 0.0
# P_In_29_13 = 0.0
# P_In_29_14 = 0.0
# P_In_29_15 = 0.0
# P_In_29_16 = 0.0
# P_In_29_17 = 0.0
# P_In_29_18 = 0.0
# P_In_29_19 = 0.0
# P_In_29_2 = 0.0
# P_In_29_20 = 0.0
# P_In_29_21 = 0.0
# P_In_29_22 = 0.0
# P_In_29_23 = 0.0
# P_In_29_24 = 0.0
# P_In_29_25 = 0.0
# P_In_29_26 = 0.0
# P_In_29_27 = 0.0
# P_In_29_28 = 0.0
# P_In_29_29 = 0.0
# P_In_29_3 = 0.0
# P_In_29_4 = 0.0
# P_In_29_5 = 0.0
# P_In_29_6 = 0.0
# P_In_29_7 = 0.0
# P_In_29_8 = 0.0
# P_In_29_9 = 0.0
# P_In_2_0 = 0.0
# P_In_2_1 = 0.0
# P_In_2_10 = 0.0
# P_In_2_11 = 0.0
# P_In_2_12 = 0.0
# P_In_2_13 = 0.0
# P_In_2_14 = 0.0
# P_In_2_15 = 0.0
# P_In_2_16 = 0.0
# P_In_2_17 = 0.0
# P_In_2_18 = 0.0
# P_In_2_19 = 0.0
# P_In_2_2 = 0.0
# P_In_2_20 = 0.0
# P_In_2_21 = 0.0
# P_In_2_22 = 413.07064
# P_In_2_23 = 0.0
# P_In_2_24 = 0.0
# P_In_2_25 = 0.0
# P_In_2_26 = 0.0
# P_In_2_27 = 0.0
# P_In_2_28 = 0.0
# P_In_2_29 = 0.0
# P_In_2_3 = 0.0
# P_In_2_4 = 0.0
# P_In_2_5 = 0.0
# P_In_2_6 = 0.0
# P_In_2_7 = 0.0
# P_In_2_8 = 0.0
# P_In_2_9 = 0.0
# P_In_3_0 = 0.0
# P_In_3_1 = 0.0
# P_In_3_10 = 0.0
# P_In_3_11 = 0.0
# P_In_3_12 = 0.0
# P_In_3_13 = 0.0
# P_In_3_14 = 357.89902
# P_In_3_15 = 0.0
# P_In_3_16 = 0.0
# P_In_3_17 = 0.0
# P_In_3_18 = 0.0
# P_In_3_19 = 8138.8514
# P_In_3_2 = 0.0
# P_In_3_20 = 0.0
# P_In_3_21 = 0.0
# P_In_3_22 = 0.0
# P_In_3_23 = 0.0
# P_In_3_24 = 0.0
# P_In_3_25 = 0.0
# P_In_3_26 = 0.0
# P_In_3_27 = 0.0
# P_In_3_28 = 0.0
# P_In_3_29 = 0.0
# P_In_3_3 = 0.0
# P_In_3_4 = 0.0
# P_In_3_5 = 0.0
# P_In_3_6 = 0.0
# P_In_3_7 = 0.0
# P_In_3_8 = 1376.2376
# P_In_3_9 = 0.0
# P_In_4_0 = 0.0
# P_In_4_1 = 0.0
# P_In_4_10 = 0.0
# P_In_4_11 = 0.0
# P_In_4_12 = 0.0
# P_In_4_13 = 0.0
# P_In_4_14 = 0.0
# P_In_4_15 = 0.0
# P_In_4_16 = 0.0
# P_In_4_17 = 0.0
# P_In_4_18 = 0.0
# P_In_4_19 = 0.0
# P_In_4_2 = 0.0
# P_In_4_20 = 0.0
# P_In_4_21 = 0.0
# P_In_4_22 = 0.0
# P_In_4_23 = 0.0
# P_In_4_24 = 0.0
# P_In_4_25 = 0.0
# P_In_4_26 = 0.0
# P_In_4_27 = 0.0
# P_In_4_28 = 0.0
# P_In_4_29 = 0.0
# P_In_4_3 = 0.0
# P_In_4_4 = 0.0
# P_In_4_5 = 0.0
# P_In_4_6 = 0.0
# P_In_4_7 = 0.0
# P_In_4_8 = 0.0
# P_In_4_9 = 1784.6294
# P_In_5_0 = 0.0
# P_In_5_1 = 0.0
# P_In_5_10 = 0.0
# P_In_5_11 = 0.0
# P_In_5_12 = 0.0
# P_In_5_13 = 0.0
# P_In_5_14 = 0.0
# P_In_5_15 = 0.0
# P_In_5_16 = 0.0
# P_In_5_17 = 0.0
# P_In_5_18 = 0.0
# P_In_5_19 = 0.0
# P_In_5_2 = 0.0
# P_In_5_20 = 0.0
# P_In_5_21 = 0.0
# P_In_5_22 = 0.0
# P_In_5_23 = 0.0
# P_In_5_24 = 0.0
# P_In_5_25 = 0.0
# P_In_5_26 = 0.0
# P_In_5_27 = 0.0
# P_In_5_28 = 950.91861
# P_In_5_29 = 0.0
# P_In_5_3 = 0.0
# P_In_5_4 = 0.0
# P_In_5_5 = 0.0
# P_In_5_6 = 0.0
# P_In_5_7 = 0.0
# P_In_5_8 = 0.0
# P_In_5_9 = 0.0
# P_In_6_0 = 1400.6395
# P_In_6_1 = 0.0
# P_In_6_10 = 0.0
# P_In_6_11 = 0.0
# P_In_6_12 = 0.0
# P_In_6_13 = 0.0
# P_In_6_14 = 0.0
# P_In_6_15 = 0.0
# P_In_6_16 = 0.0
# P_In_6_17 = 0.0
# P_In_6_18 = 0.0
# P_In_6_19 = 0.0
# P_In_6_2 = 0.0
# P_In_6_20 = 0.0
# P_In_6_21 = 0.0
# P_In_6_22 = 0.0
# P_In_6_23 = 0.0
# P_In_6_24 = 0.0
# P_In_6_25 = 0.0
# P_In_6_26 = 0.0
# P_In_6_27 = 0.0
# P_In_6_28 = 0.0
# P_In_6_29 = 0.0
# P_In_6_3 = 0.0
# P_In_6_4 = 0.0
# P_In_6_5 = 0.0
# P_In_6_6 = 0.0
# P_In_6_7 = 0.0
# P_In_6_8 = 0.0
# P_In_6_9 = 0.0
# P_In_7_0 = 0.0
# P_In_7_1 = 0.0
# P_In_7_10 = 0.0
# P_In_7_11 = 0.0
# P_In_7_12 = 0.0
# P_In_7_13 = 0.0
# P_In_7_14 = 0.0
# P_In_7_15 = 0.0
# P_In_7_16 = 0.0
# P_In_7_17 = 0.0
# P_In_7_18 = 0.0
# P_In_7_19 = 0.0
# P_In_7_2 = 570.17373
# P_In_7_20 = 0.0
# P_In_7_21 = 0.0
# P_In_7_22 = 0.0
# P_In_7_23 = 0.0
# P_In_7_24 = 0.0
# P_In_7_25 = 0.0
# P_In_7_26 = 0.0
# P_In_7_27 = 0.0
# P_In_7_28 = 0.0
# P_In_7_29 = 0.0
# P_In_7_3 = 0.0
# P_In_7_4 = 0.0
# P_In_7_5 = 0.0
# P_In_7_6 = 0.0
# P_In_7_7 = 0.0
# P_In_7_8 = 0.0
# P_In_7_9 = 0.0
# P_In_8_0 = 0.0
# P_In_8_1 = 0.0
# P_In_8_10 = 1132.0812
# P_In_8_11 = 0.0
# P_In_8_12 = 0.0
# P_In_8_13 = 0.0
# P_In_8_14 = 0.0
# P_In_8_15 = 0.0
# P_In_8_16 = 0.0
# P_In_8_17 = 0.0
# P_In_8_18 = 0.0
# P_In_8_19 = 0.0
# P_In_8_2 = 0.0
# P_In_8_20 = 0.0
# P_In_8_21 = 0.0
# P_In_8_22 = 0.0
# P_In_8_23 = 0.0
# P_In_8_24 = 0.0
# P_In_8_25 = 0.0
# P_In_8_26 = 0.0
# P_In_8_27 = 0.0
# P_In_8_28 = 0.0
# P_In_8_29 = 0.0
# P_In_8_3 = 0.0
# P_In_8_4 = 0.0
# P_In_8_5 = 0.0
# P_In_8_6 = 0.0
# P_In_8_7 = 0.0
# P_In_8_8 = 0.0
# P_In_8_9 = 0.0
# P_In_9_0 = 0.0
# P_In_9_1 = 0.0
# P_In_9_10 = 0.0
# P_In_9_11 = 0.0
# P_In_9_12 = 0.0
# P_In_9_13 = 0.0
# P_In_9_14 = 0.0
# P_In_9_15 = 0.0
# P_In_9_16 = 0.0
# P_In_9_17 = 0.0
# P_In_9_18 = 0.0
# P_In_9_19 = 0.0
# P_In_9_2 = 0.0
# P_In_9_20 = 0.0
# P_In_9_21 = 0.0
# P_In_9_22 = 0.0
# P_In_9_23 = 0.0
# P_In_9_24 = 0.0
# P_In_9_25 = 0.0
# P_In_9_26 = 0.0
# P_In_9_27 = 0.0
# P_In_9_28 = 0.0
# P_In_9_29 = 0.0
# P_In_9_3 = 0.0
# P_In_9_4 = 0.0
# P_In_9_5 = 1183.748
# P_In_9_6 = 0.0
# P_In_9_7 = 0.0
# P_In_9_8 = 0.0
# P_In_9_9 = 0.0
# P_Out_0_0 = 0.0
# P_Out_0_1 = 0.0
# P_Out_0_10 = 0.0
# P_Out_0_11 = 0.0
# P_Out_0_12 = 0.0
# P_Out_0_13 = 0.0
# P_Out_0_14 = 0.0
# P_Out_0_15 = 0.0
# P_Out_0_16 = 0.0
# P_Out_0_17 = 0.0
# P_Out_0_18 = 0.0
# P_Out_0_19 = 0.0
# P_Out_0_2 = 0.0
# P_Out_0_20 = 0.0
# P_Out_0_21 = 0.0
# P_Out_0_22 = 0.0
# P_Out_0_23 = 0.0
# P_Out_0_24 = 0.0
# P_Out_0_25 = 439.90875
# P_Out_0_26 = 0.0
# P_Out_0_27 = 0.0
# P_Out_0_28 = 0.0
# P_Out_0_29 = 0.0
# P_Out_0_3 = 0.0
# P_Out_0_4 = 0.0
# P_Out_0_5 = 0.0
# P_Out_0_6 = 0.0
# P_Out_0_7 = 0.0
# P_Out_0_8 = 0.0
# P_Out_0_9 = 0.0
# P_Out_10_0 = 0.0
# P_Out_10_1 = 0.0
# P_Out_10_10 = 0.0
# P_Out_10_11 = 0.0
# P_Out_10_12 = 0.0
# P_Out_10_13 = 0.0
# P_Out_10_14 = 0.0
# P_Out_10_15 = 0.0
# P_Out_10_16 = 0.0
# P_Out_10_17 = 0.0
# P_Out_10_18 = 0.0
# P_Out_10_19 = 0.0
# P_Out_10_2 = 0.0
# P_Out_10_20 = 0.0
# P_Out_10_21 = 0.0
# P_Out_10_22 = 0.0
# P_Out_10_23 = 0.0
# P_Out_10_24 = 0.0
# P_Out_10_25 = 0.0
# P_Out_10_26 = 0.0
# P_Out_10_27 = 0.0
# P_Out_10_28 = 0.0
# P_Out_10_29 = 0.0
# P_Out_10_3 = 0.0
# P_Out_10_4 = 0.0
# P_Out_10_5 = 0.0
# P_Out_10_6 = 0.0
# P_Out_10_7 = 570.17373
# P_Out_10_8 = 0.0
# P_Out_10_9 = 0.0
# P_Out_11_0 = 0.0
# P_Out_11_1 = 0.0
# P_Out_11_10 = 0.0
# P_Out_11_11 = 0.0
# P_Out_11_12 = 0.0
# P_Out_11_13 = 0.0
# P_Out_11_14 = 0.0
# P_Out_11_15 = 0.0
# P_Out_11_16 = 0.0
# P_Out_11_17 = 0.0
# P_Out_11_18 = 0.0
# P_Out_11_19 = 0.0
# P_Out_11_2 = 0.0
# P_Out_11_20 = 0.0
# P_Out_11_21 = 0.0
# P_Out_11_22 = 0.0
# P_Out_11_23 = 0.0
# P_Out_11_24 = 0.0
# P_Out_11_25 = 0.0
# P_Out_11_26 = 0.0
# P_Out_11_27 = 0.0
# P_Out_11_28 = 0.0
# P_Out_11_29 = 0.0
# P_Out_11_3 = 0.0
# P_Out_11_4 = 0.0
# P_Out_11_5 = 0.0
# P_Out_11_6 = 0.0
# P_Out_11_7 = 0.0
# P_Out_11_8 = 0.0
# P_Out_11_9 = 0.0
# P_Out_12_0 = 0.0
# P_Out_12_1 = 0.0
# P_Out_12_10 = 0.0
# P_Out_12_11 = 121.22882
# P_Out_12_12 = 0.0
# P_Out_12_13 = 0.0
# P_Out_12_14 = 0.0
# P_Out_12_15 = 0.0
# P_Out_12_16 = 0.0
# P_Out_12_17 = 0.0
# P_Out_12_18 = 0.0
# P_Out_12_19 = 0.0
# P_Out_12_2 = 0.0
# P_Out_12_20 = 0.0
# P_Out_12_21 = 0.0
# P_Out_12_22 = 0.0
# P_Out_12_23 = 0.0
# P_Out_12_24 = 0.0
# P_Out_12_25 = 0.0
# P_Out_12_26 = 0.0
# P_Out_12_27 = 0.0
# P_Out_12_28 = 0.0
# P_Out_12_29 = 0.0
# P_Out_12_3 = 0.0
# P_Out_12_4 = 0.0
# P_Out_12_5 = 0.0
# P_Out_12_6 = 0.0
# P_Out_12_7 = 0.0
# P_Out_12_8 = 0.0
# P_Out_12_9 = 0.0
# P_Out_13_0 = 0.0
# P_Out_13_1 = 0.0
# P_Out_13_10 = 0.0
# P_Out_13_11 = 0.0
# P_Out_13_12 = 0.0
# P_Out_13_13 = 0.0
# P_Out_13_14 = 0.0
# P_Out_13_15 = 0.0
# P_Out_13_16 = 0.0
# P_Out_13_17 = 0.0
# P_Out_13_18 = 0.0
# P_Out_13_19 = 0.0
# P_Out_13_2 = 0.0
# P_Out_13_20 = 0.0
# P_Out_13_21 = 0.0
# P_Out_13_22 = 0.0
# P_Out_13_23 = 374.59924
# P_Out_13_24 = 0.0
# P_Out_13_25 = 0.0
# P_Out_13_26 = 0.0
# P_Out_13_27 = 0.0
# P_Out_13_28 = 0.0
# P_Out_13_29 = 0.0
# P_Out_13_3 = 0.0
# P_Out_13_4 = 0.0
# P_Out_13_5 = 0.0
# P_Out_13_6 = 0.0
# P_Out_13_7 = 0.0
# P_Out_13_8 = 0.0
# P_Out_13_9 = 0.0
# P_Out_14_0 = 0.0
# P_Out_14_1 = 0.0
# P_Out_14_10 = 0.0
# P_Out_14_11 = 0.0
# P_Out_14_12 = 0.0
# P_Out_14_13 = 0.0
# P_Out_14_14 = 0.0
# P_Out_14_15 = 0.0
# P_Out_14_16 = 0.0
# P_Out_14_17 = 0.0
# P_Out_14_18 = 0.0
# P_Out_14_19 = 0.0
# P_Out_14_2 = 0.0
# P_Out_14_20 = 0.0
# P_Out_14_21 = 0.0
# P_Out_14_22 = 0.0
# P_Out_14_23 = 0.0
# P_Out_14_24 = 0.0
# P_Out_14_25 = 0.0
# P_Out_14_26 = 0.0
# P_Out_14_27 = 0.0
# P_Out_14_28 = 0.0
# P_Out_14_29 = 0.0
# P_Out_14_3 = 0.0
# P_Out_14_4 = 0.0
# P_Out_14_5 = 0.0
# P_Out_14_6 = 0.0
# P_Out_14_7 = 0.0
# P_Out_14_8 = 0.0
# P_Out_14_9 = 0.0
# P_Out_15_0 = 0.0
# P_Out_15_1 = 0.0
# P_Out_15_10 = 0.0
# P_Out_15_11 = 0.0
# P_Out_15_12 = 0.0
# P_Out_15_13 = 0.0
# P_Out_15_14 = 0.0
# P_Out_15_15 = 0.0
# P_Out_15_16 = 0.0
# P_Out_15_17 = 0.0
# P_Out_15_18 = 0.0
# P_Out_15_19 = 0.0
# P_Out_15_2 = 0.0
# P_Out_15_20 = 0.0
# P_Out_15_21 = 0.0
# P_Out_15_22 = 0.0
# P_Out_15_23 = 0.0
# P_Out_15_24 = 0.0
# P_Out_15_25 = 0.0
# P_Out_15_26 = 0.0
# P_Out_15_27 = 0.0
# P_Out_15_28 = 0.0
# P_Out_15_29 = 0.0
# P_Out_15_3 = 0.0
# P_Out_15_4 = 0.0
# P_Out_15_5 = 0.0
# P_Out_15_6 = 0.0
# P_Out_15_7 = 0.0
# P_Out_15_8 = 0.0
# P_Out_15_9 = 0.0
# P_Out_16_0 = 0.0
# P_Out_16_1 = 0.0
# P_Out_16_10 = 0.0
# P_Out_16_11 = 0.0
# P_Out_16_12 = 0.0
# P_Out_16_13 = 0.0
# P_Out_16_14 = 0.0
# P_Out_16_15 = 0.0
# P_Out_16_16 = 0.0
# P_Out_16_17 = 0.0
# P_Out_16_18 = 0.0
# P_Out_16_19 = 0.0
# P_Out_16_2 = 0.0
# P_Out_16_20 = 0.0
# P_Out_16_21 = 0.0
# P_Out_16_22 = 0.0
# P_Out_16_23 = 0.0
# P_Out_16_24 = 0.0
# P_Out_16_25 = 0.0
# P_Out_16_26 = 0.0
# P_Out_16_27 = 0.0
# P_Out_16_28 = 0.0
# P_Out_16_29 = 0.0
# P_Out_16_3 = 0.0
# P_Out_16_4 = 0.0
# P_Out_16_5 = 0.0
# P_Out_16_6 = 0.0
# P_Out_16_7 = 0.0
# P_Out_16_8 = 0.0
# P_Out_16_9 = 0.0
# P_Out_17_0 = 0.0
# P_Out_17_1 = 0.0
# P_Out_17_10 = 0.0
# P_Out_17_11 = 0.0
# P_Out_17_12 = 655.58933
# P_Out_17_13 = 0.0
# P_Out_17_14 = 0.0
# P_Out_17_15 = 0.0
# P_Out_17_16 = 0.0
# P_Out_17_17 = 0.0
# P_Out_17_18 = 0.0
# P_Out_17_19 = 0.0
# P_Out_17_2 = 0.0
# P_Out_17_20 = 0.0
# P_Out_17_21 = 0.0
# P_Out_17_22 = 0.0
# P_Out_17_23 = 0.0
# P_Out_17_24 = 0.0
# P_Out_17_25 = 0.0
# P_Out_17_26 = 0.0
# P_Out_17_27 = 0.0
# P_Out_17_28 = 0.0
# P_Out_17_29 = 0.0
# P_Out_17_3 = 0.0
# P_Out_17_4 = 0.0
# P_Out_17_5 = 0.0
# P_Out_17_6 = 0.0
# P_Out_17_7 = 0.0
# P_Out_17_8 = 0.0
# P_Out_17_9 = 0.0
# P_Out_18_0 = 0.0
# P_Out_18_1 = 2287.4729
# P_Out_18_10 = 0.0
# P_Out_18_11 = 0.0
# P_Out_18_12 = 0.0
# P_Out_18_13 = 0.0
# P_Out_18_14 = 0.0
# P_Out_18_15 = 0.0
# P_Out_18_16 = 0.0
# P_Out_18_17 = 0.0
# P_Out_18_18 = 0.0
# P_Out_18_19 = 0.0
# P_Out_18_2 = 0.0
# P_Out_18_20 = 0.0
# P_Out_18_21 = 0.0
# P_Out_18_22 = 0.0
# P_Out_18_23 = 0.0
# P_Out_18_24 = 0.0
# P_Out_18_25 = 0.0
# P_Out_18_26 = 0.0
# P_Out_18_27 = 0.0
# P_Out_18_28 = 0.0
# P_Out_18_29 = 0.0
# P_Out_18_3 = 0.0
# P_Out_18_4 = 0.0
# P_Out_18_5 = 0.0
# P_Out_18_6 = 0.0
# P_Out_18_7 = 0.0
# P_Out_18_8 = 0.0
# P_Out_18_9 = 0.0
# P_Out_19_0 = 0.0
# P_Out_19_1 = 0.0
# P_Out_19_10 = 0.0
# P_Out_19_11 = 0.0
# P_Out_19_12 = 0.0
# P_Out_19_13 = 0.0
# P_Out_19_14 = 0.0
# P_Out_19_15 = 0.0
# P_Out_19_16 = 0.0
# P_Out_19_17 = 0.0
# P_Out_19_18 = 2796.6175
# P_Out_19_19 = 0.0
# P_Out_19_2 = 0.0
# P_Out_19_20 = 0.0
# P_Out_19_21 = 4029.4369
# P_Out_19_22 = 0.0
# P_Out_19_23 = 0.0
# P_Out_19_24 = 0.0
# P_Out_19_25 = 0.0
# P_Out_19_26 = 0.0
# P_Out_19_27 = 0.0
# P_Out_19_28 = 0.0
# P_Out_19_29 = 0.0
# P_Out_19_3 = 0.0
# P_Out_19_4 = 0.0
# P_Out_19_5 = 0.0
# P_Out_19_6 = 0.0
# P_Out_19_7 = 0.0
# P_Out_19_8 = 0.0
# P_Out_19_9 = 0.0
# P_Out_1_0 = 0.0
# P_Out_1_1 = 0.0
# P_Out_1_10 = 0.0
# P_Out_1_11 = 0.0
# P_Out_1_12 = 0.0
# P_Out_1_13 = 0.0
# P_Out_1_14 = 0.0
# P_Out_1_15 = 0.0
# P_Out_1_16 = 0.0
# P_Out_1_17 = 0.0
# P_Out_1_18 = 0.0
# P_Out_1_19 = 0.0
# P_Out_1_2 = 0.0
# P_Out_1_20 = 1606.3178
# P_Out_1_21 = 0.0
# P_Out_1_22 = 0.0
# P_Out_1_23 = 0.0
# P_Out_1_24 = 0.0
# P_Out_1_25 = 0.0
# P_Out_1_26 = 0.0
# P_Out_1_27 = 0.0
# P_Out_1_28 = 0.0
# P_Out_1_29 = 0.0
# P_Out_1_3 = 0.0
# P_Out_1_4 = 0.0
# P_Out_1_5 = 0.0
# P_Out_1_6 = 0.0
# P_Out_1_7 = 0.0
# P_Out_1_8 = 0.0
# P_Out_1_9 = 0.0
# P_Out_20_0 = 0.0
# P_Out_20_1 = 0.0
# P_Out_20_10 = 0.0
# P_Out_20_11 = 0.0
# P_Out_20_12 = 0.0
# P_Out_20_13 = 0.0
# P_Out_20_14 = 0.0
# P_Out_20_15 = 0.0
# P_Out_20_16 = 0.0
# P_Out_20_17 = 1069.7446
# P_Out_20_18 = 0.0
# P_Out_20_19 = 0.0
# P_Out_20_2 = 0.0
# P_Out_20_20 = 0.0
# P_Out_20_21 = 0.0
# P_Out_20_22 = 0.0
# P_Out_20_23 = 0.0
# P_Out_20_24 = 0.0
# P_Out_20_25 = 0.0
# P_Out_20_26 = 0.0
# P_Out_20_27 = 0.0
# P_Out_20_28 = 0.0
# P_Out_20_29 = 0.0
# P_Out_20_3 = 0.0
# P_Out_20_4 = 0.0
# P_Out_20_5 = 0.0
# P_Out_20_6 = 0.0
# P_Out_20_7 = 0.0
# P_Out_20_8 = 0.0
# P_Out_20_9 = 0.0
# P_Out_21_0 = 0.0
# P_Out_21_1 = 0.0
# P_Out_21_10 = 0.0
# P_Out_21_11 = 0.0
# P_Out_21_12 = 0.0
# P_Out_21_13 = 0.0
# P_Out_21_14 = 0.0
# P_Out_21_15 = 0.0
# P_Out_21_16 = 0.0
# P_Out_21_17 = 0.0
# P_Out_21_18 = 0.0
# P_Out_21_19 = 0.0
# P_Out_21_2 = 0.0
# P_Out_21_20 = 0.0
# P_Out_21_21 = 0.0
# P_Out_21_22 = 0.0
# P_Out_21_23 = 0.0
# P_Out_21_24 = 0.0
# P_Out_21_25 = 0.0
# P_Out_21_26 = 0.0
# P_Out_21_27 = 0.0
# P_Out_21_28 = 0.0
# P_Out_21_29 = 0.0
# P_Out_21_3 = 0.0
# P_Out_21_4 = 1784.6294
# P_Out_21_5 = 0.0
# P_Out_21_6 = 1400.6395
# P_Out_21_7 = 0.0
# P_Out_21_8 = 0.0
# P_Out_21_9 = 0.0
# P_Out_22_0 = 0.0
# P_Out_22_1 = 0.0
# P_Out_22_10 = 0.0
# P_Out_22_11 = 0.0
# P_Out_22_12 = 0.0
# P_Out_22_13 = 0.0
# P_Out_22_14 = 0.0
# P_Out_22_15 = 0.0
# P_Out_22_16 = 0.0
# P_Out_22_17 = 0.0
# P_Out_22_18 = 0.0
# P_Out_22_19 = 0.0
# P_Out_22_2 = 0.0
# P_Out_22_20 = 0.0
# P_Out_22_21 = 0.0
# P_Out_22_22 = 0.0
# P_Out_22_23 = 0.0
# P_Out_22_24 = 0.0
# P_Out_22_25 = 0.0
# P_Out_22_26 = 0.0
# P_Out_22_27 = 0.0
# P_Out_22_28 = 0.0
# P_Out_22_29 = 0.0
# P_Out_22_3 = 0.0
# P_Out_22_4 = 0.0
# P_Out_22_5 = 0.0
# P_Out_22_6 = 0.0
# P_Out_22_7 = 0.0
# P_Out_22_8 = 0.0
# P_Out_22_9 = 0.0
# P_Out_23_0 = 0.0
# P_Out_23_1 = 0.0
# P_Out_23_10 = 0.0
# P_Out_23_11 = 0.0
# P_Out_23_12 = 0.0
# P_Out_23_13 = 0.0
# P_Out_23_14 = 0.0
# P_Out_23_15 = 0.0
# P_Out_23_16 = 0.0
# P_Out_23_17 = 0.0
# P_Out_23_18 = 0.0
# P_Out_23_19 = 0.0
# P_Out_23_2 = 0.0
# P_Out_23_20 = 0.0
# P_Out_23_21 = 0.0
# P_Out_23_22 = 0.0
# P_Out_23_23 = 0.0
# P_Out_23_24 = 0.0
# P_Out_23_25 = 0.0
# P_Out_23_26 = 90.309604
# P_Out_23_27 = 0.0
# P_Out_23_28 = 0.0
# P_Out_23_29 = 0.0
# P_Out_23_3 = 0.0
# P_Out_23_4 = 0.0
# P_Out_23_5 = 0.0
# P_Out_23_6 = 0.0
# P_Out_23_7 = 0.0
# P_Out_23_8 = 0.0
# P_Out_23_9 = 0.0
# P_Out_24_0 = 0.0
# P_Out_24_1 = 0.0
# P_Out_24_10 = 0.0
# P_Out_24_11 = 0.0
# P_Out_24_12 = 0.0
# P_Out_24_13 = 0.0
# P_Out_24_14 = 0.0
# P_Out_24_15 = 0.0
# P_Out_24_16 = 0.0
# P_Out_24_17 = 0.0
# P_Out_24_18 = 0.0
# P_Out_24_19 = 0.0
# P_Out_24_2 = 0.0
# P_Out_24_20 = 0.0
# P_Out_24_21 = 0.0
# P_Out_24_22 = 0.0
# P_Out_24_23 = 0.0
# P_Out_24_24 = 0.0
# P_Out_24_25 = 0.0
# P_Out_24_26 = 0.0
# P_Out_24_27 = 0.0
# P_Out_24_28 = 0.0
# P_Out_24_29 = 0.0
# P_Out_24_3 = 0.0
# P_Out_24_4 = 0.0
# P_Out_24_5 = 0.0
# P_Out_24_6 = 0.0
# P_Out_24_7 = 0.0
# P_Out_24_8 = 0.0
# P_Out_24_9 = 0.0
# P_Out_25_0 = 0.0
# P_Out_25_1 = 0.0
# P_Out_25_10 = 0.0
# P_Out_25_11 = 0.0
# P_Out_25_12 = 0.0
# P_Out_25_13 = 0.0
# P_Out_25_14 = 0.0
# P_Out_25_15 = 0.0
# P_Out_25_16 = 0.0
# P_Out_25_17 = 0.0
# P_Out_25_18 = 0.0
# P_Out_25_19 = 0.0
# P_Out_25_2 = 0.0
# P_Out_25_20 = 0.0
# P_Out_25_21 = 0.0
# P_Out_25_22 = 0.0
# P_Out_25_23 = 0.0
# P_Out_25_24 = 0.0
# P_Out_25_25 = 0.0
# P_Out_25_26 = 0.0
# P_Out_25_27 = 0.0
# P_Out_25_28 = 0.0
# P_Out_25_29 = 0.0
# P_Out_25_3 = 0.0
# P_Out_25_4 = 0.0
# P_Out_25_5 = 0.0
# P_Out_25_6 = 0.0
# P_Out_25_7 = 0.0
# P_Out_25_8 = 0.0
# P_Out_25_9 = 0.0
# P_Out_26_0 = 0.0
# P_Out_26_1 = 0.0
# P_Out_26_10 = 0.0
# P_Out_26_11 = 0.0
# P_Out_26_12 = 0.0
# P_Out_26_13 = 0.0
# P_Out_26_14 = 0.0
# P_Out_26_15 = 0.0
# P_Out_26_16 = 0.0
# P_Out_26_17 = 0.0
# P_Out_26_18 = 0.0
# P_Out_26_19 = 0.0
# P_Out_26_2 = 0.0
# P_Out_26_20 = 0.0
# P_Out_26_21 = 0.0
# P_Out_26_22 = 0.0
# P_Out_26_23 = 0.0
# P_Out_26_24 = 0.0
# P_Out_26_25 = 0.0
# P_Out_26_26 = 0.0
# P_Out_26_27 = 0.0
# P_Out_26_28 = 0.0
# P_Out_26_29 = 0.0
# P_Out_26_3 = 0.0
# P_Out_26_4 = 0.0
# P_Out_26_5 = 0.0
# P_Out_26_6 = 0.0
# P_Out_26_7 = 0.0
# P_Out_26_8 = 0.0
# P_Out_26_9 = 0.0
# P_Out_27_0 = 0.0
# P_Out_27_1 = 0.0
# P_Out_27_10 = 0.0
# P_Out_27_11 = 0.0
# P_Out_27_12 = 0.0
# P_Out_27_13 = 0.0
# P_Out_27_14 = 0.0
# P_Out_27_15 = 0.0
# P_Out_27_16 = 0.0
# P_Out_27_17 = 0.0
# P_Out_27_18 = 0.0
# P_Out_27_19 = 0.0
# P_Out_27_2 = 0.0
# P_Out_27_20 = 0.0
# P_Out_27_21 = 0.0
# P_Out_27_22 = 0.0
# P_Out_27_23 = 0.0
# P_Out_27_24 = 0.0
# P_Out_27_25 = 0.0
# P_Out_27_26 = 0.0
# P_Out_27_27 = 0.0
# P_Out_27_28 = 0.0
# P_Out_27_29 = 0.0
# P_Out_27_3 = 0.0
# P_Out_27_4 = 0.0
# P_Out_27_5 = 0.0
# P_Out_27_6 = 0.0
# P_Out_27_7 = 0.0
# P_Out_27_8 = 0.0
# P_Out_27_9 = 0.0
# P_Out_28_0 = 0.0
# P_Out_28_1 = 0.0
# P_Out_28_10 = 0.0
# P_Out_28_11 = 0.0
# P_Out_28_12 = 0.0
# P_Out_28_13 = 504.93458
# P_Out_28_14 = 0.0
# P_Out_28_15 = 0.0
# P_Out_28_16 = 0.0
# P_Out_28_17 = 0.0
# P_Out_28_18 = 0.0
# P_Out_28_19 = 0.0
# P_Out_28_2 = 0.0
# P_Out_28_20 = 0.0
# P_Out_28_21 = 0.0
# P_Out_28_22 = 0.0
# P_Out_28_23 = 0.0
# P_Out_28_24 = 0.0
# P_Out_28_25 = 0.0
# P_Out_28_26 = 0.0
# P_Out_28_27 = 0.0
# P_Out_28_28 = 0.0
# P_Out_28_29 = 0.0
# P_Out_28_3 = 0.0
# P_Out_28_4 = 0.0
# P_Out_28_5 = 0.0
# P_Out_28_6 = 0.0
# P_Out_28_7 = 0.0
# P_Out_28_8 = 0.0
# P_Out_28_9 = 0.0
# P_Out_29_0 = 0.0
# P_Out_29_1 = 0.0
# P_Out_29_10 = 0.0
# P_Out_29_11 = 0.0
# P_Out_29_12 = 0.0
# P_Out_29_13 = 0.0
# P_Out_29_14 = 0.0
# P_Out_29_15 = 0.0
# P_Out_29_16 = 0.0
# P_Out_29_17 = 0.0
# P_Out_29_18 = 0.0
# P_Out_29_19 = 0.0
# P_Out_29_2 = 0.0
# P_Out_29_20 = 0.0
# P_Out_29_21 = 0.0
# P_Out_29_22 = 0.0
# P_Out_29_23 = 0.0
# P_Out_29_24 = 0.0
# P_Out_29_25 = 0.0
# P_Out_29_26 = 0.0
# P_Out_29_27 = 0.0
# P_Out_29_28 = 0.0
# P_Out_29_29 = 0.0
# P_Out_29_3 = 0.0
# P_Out_29_4 = 0.0
# P_Out_29_5 = 0.0
# P_Out_29_6 = 0.0
# P_Out_29_7 = 0.0
# P_Out_29_8 = 0.0
# P_Out_29_9 = 0.0
# P_Out_2_0 = 0.0
# P_Out_2_1 = 0.0
# P_Out_2_10 = 0.0
# P_Out_2_11 = 0.0
# P_Out_2_12 = 0.0
# P_Out_2_13 = 0.0
# P_Out_2_14 = 0.0
# P_Out_2_15 = 0.0
# P_Out_2_16 = 0.0
# P_Out_2_17 = 0.0
# P_Out_2_18 = 0.0
# P_Out_2_19 = 0.0
# P_Out_2_2 = 0.0
# P_Out_2_20 = 0.0
# P_Out_2_21 = 0.0
# P_Out_2_22 = 139.63932
# P_Out_2_23 = 0.0
# P_Out_2_24 = 0.0
# P_Out_2_25 = 0.0
# P_Out_2_26 = 0.0
# P_Out_2_27 = 0.0
# P_Out_2_28 = 0.0
# P_Out_2_29 = 0.0
# P_Out_2_3 = 0.0
# P_Out_2_4 = 0.0
# P_Out_2_5 = 0.0
# P_Out_2_6 = 0.0
# P_Out_2_7 = 0.0
# P_Out_2_8 = 0.0
# P_Out_2_9 = 0.0
# P_Out_3_0 = 0.0
# P_Out_3_1 = 0.0
# P_Out_3_10 = 0.0
# P_Out_3_11 = 0.0
# P_Out_3_12 = 0.0
# P_Out_3_13 = 0.0
# P_Out_3_14 = 0.0
# P_Out_3_15 = 0.0
# P_Out_3_16 = 0.0
# P_Out_3_17 = 0.0
# P_Out_3_18 = 0.0
# P_Out_3_19 = 7664.7905
# P_Out_3_2 = 0.0
# P_Out_3_20 = 0.0
# P_Out_3_21 = 0.0
# P_Out_3_22 = 0.0
# P_Out_3_23 = 0.0
# P_Out_3_24 = 0.0
# P_Out_3_25 = 0.0
# P_Out_3_26 = 0.0
# P_Out_3_27 = 0.0
# P_Out_3_28 = 0.0
# P_Out_3_29 = 0.0
# P_Out_3_3 = 0.0
# P_Out_3_4 = 0.0
# P_Out_3_5 = 0.0
# P_Out_3_6 = 0.0
# P_Out_3_7 = 0.0
# P_Out_3_8 = 1132.0812
# P_Out_3_9 = 0.0
# P_Out_4_0 = 0.0
# P_Out_4_1 = 0.0
# P_Out_4_10 = 0.0
# P_Out_4_11 = 0.0
# P_Out_4_12 = 0.0
# P_Out_4_13 = 0.0
# P_Out_4_14 = 0.0
# P_Out_4_15 = 0.0
# P_Out_4_16 = 0.0
# P_Out_4_17 = 0.0
# P_Out_4_18 = 0.0
# P_Out_4_19 = 0.0
# P_Out_4_2 = 0.0
# P_Out_4_20 = 0.0
# P_Out_4_21 = 0.0
# P_Out_4_22 = 0.0
# P_Out_4_23 = 0.0
# P_Out_4_24 = 0.0
# P_Out_4_25 = 0.0
# P_Out_4_26 = 0.0
# P_Out_4_27 = 0.0
# P_Out_4_28 = 0.0
# P_Out_4_29 = 0.0
# P_Out_4_3 = 0.0
# P_Out_4_4 = 0.0
# P_Out_4_5 = 0.0
# P_Out_4_6 = 0.0
# P_Out_4_7 = 0.0
# P_Out_4_8 = 0.0
# P_Out_4_9 = 1183.748
# P_Out_5_0 = 0.0
# P_Out_5_1 = 0.0
# P_Out_5_10 = 0.0
# P_Out_5_11 = 0.0
# P_Out_5_12 = 0.0
# P_Out_5_13 = 0.0
# P_Out_5_14 = 0.0
# P_Out_5_15 = 0.0
# P_Out_5_16 = 0.0
# P_Out_5_17 = 0.0
# P_Out_5_18 = 0.0
# P_Out_5_19 = 0.0
# P_Out_5_2 = 0.0
# P_Out_5_20 = 0.0
# P_Out_5_21 = 0.0
# P_Out_5_22 = 0.0
# P_Out_5_23 = 0.0
# P_Out_5_24 = 0.0
# P_Out_5_25 = 0.0
# P_Out_5_26 = 0.0
# P_Out_5_27 = 0.0
# P_Out_5_28 = 692.55936
# P_Out_5_29 = 0.0
# P_Out_5_3 = 0.0
# P_Out_5_4 = 0.0
# P_Out_5_5 = 0.0
# P_Out_5_6 = 0.0
# P_Out_5_7 = 0.0
# P_Out_5_8 = 0.0
# P_Out_5_9 = 0.0
# P_Out_6_0 = 803.49357
# P_Out_6_1 = 0.0
# P_Out_6_10 = 0.0
# P_Out_6_11 = 0.0
# P_Out_6_12 = 0.0
# P_Out_6_13 = 0.0
# P_Out_6_14 = 0.0
# P_Out_6_15 = 0.0
# P_Out_6_16 = 0.0
# P_Out_6_17 = 0.0
# P_Out_6_18 = 0.0
# P_Out_6_19 = 0.0
# P_Out_6_2 = 0.0
# P_Out_6_20 = 0.0
# P_Out_6_21 = 0.0
# P_Out_6_22 = 0.0
# P_Out_6_23 = 0.0
# P_Out_6_24 = 0.0
# P_Out_6_25 = 0.0
# P_Out_6_26 = 0.0
# P_Out_6_27 = 0.0
# P_Out_6_28 = 0.0
# P_Out_6_29 = 0.0
# P_Out_6_3 = 0.0
# P_Out_6_4 = 0.0
# P_Out_6_5 = 0.0
# P_Out_6_6 = 0.0
# P_Out_6_7 = 0.0
# P_Out_6_8 = 0.0
# P_Out_6_9 = 0.0
# P_Out_7_0 = 0.0
# P_Out_7_1 = 0.0
# P_Out_7_10 = 0.0
# P_Out_7_11 = 0.0
# P_Out_7_12 = 0.0
# P_Out_7_13 = 0.0
# P_Out_7_14 = 0.0
# P_Out_7_15 = 0.0
# P_Out_7_16 = 0.0
# P_Out_7_17 = 0.0
# P_Out_7_18 = 0.0
# P_Out_7_19 = 0.0
# P_Out_7_2 = 413.07064
# P_Out_7_20 = 0.0
# P_Out_7_21 = 0.0
# P_Out_7_22 = 0.0
# P_Out_7_23 = 0.0
# P_Out_7_24 = 0.0
# P_Out_7_25 = 0.0
# P_Out_7_26 = 0.0
# P_Out_7_27 = 0.0
# P_Out_7_28 = 0.0
# P_Out_7_29 = 0.0
# P_Out_7_3 = 0.0
# P_Out_7_4 = 0.0
# P_Out_7_5 = 0.0
# P_Out_7_6 = 0.0
# P_Out_7_7 = 0.0
# P_Out_7_8 = 0.0
# P_Out_7_9 = 0.0
# P_Out_8_0 = 0.0
# P_Out_8_1 = 0.0
# P_Out_8_10 = 926.74228
# P_Out_8_11 = 0.0
# P_Out_8_12 = 0.0
# P_Out_8_13 = 0.0
# P_Out_8_14 = 0.0
# P_Out_8_15 = 0.0
# P_Out_8_16 = 0.0
# P_Out_8_17 = 0.0
# P_Out_8_18 = 0.0
# P_Out_8_19 = 0.0
# P_Out_8_2 = 0.0
# P_Out_8_20 = 0.0
# P_Out_8_21 = 0.0
# P_Out_8_22 = 0.0
# P_Out_8_23 = 0.0
# P_Out_8_24 = 0.0
# P_Out_8_25 = 0.0
# P_Out_8_26 = 0.0
# P_Out_8_27 = 0.0
# P_Out_8_28 = 0.0
# P_Out_8_29 = 0.0
# P_Out_8_3 = 0.0
# P_Out_8_4 = 0.0
# P_Out_8_5 = 0.0
# P_Out_8_6 = 0.0
# P_Out_8_7 = 0.0
# P_Out_8_8 = 0.0
# P_Out_8_9 = 0.0
# P_Out_9_0 = 0.0
# P_Out_9_1 = 0.0
# P_Out_9_10 = 0.0
# P_Out_9_11 = 0.0
# P_Out_9_12 = 0.0
# P_Out_9_13 = 0.0
# P_Out_9_14 = 0.0
# P_Out_9_15 = 0.0
# P_Out_9_16 = 0.0
# P_Out_9_17 = 0.0
# P_Out_9_18 = 0.0
# P_Out_9_19 = 0.0
# P_Out_9_2 = 0.0
# P_Out_9_20 = 0.0
# P_Out_9_21 = 0.0
# P_Out_9_22 = 0.0
# P_Out_9_23 = 0.0
# P_Out_9_24 = 0.0
# P_Out_9_25 = 0.0
# P_Out_9_26 = 0.0
# P_Out_9_27 = 0.0
# P_Out_9_28 = 0.0
# P_Out_9_29 = 0.0
# P_Out_9_3 = 0.0
# P_Out_9_4 = 0.0
# P_Out_9_5 = 950.91861
# P_Out_9_6 = 0.0
# P_Out_9_7 = 0.0
# P_Out_9_8 = 0.0
# P_Out_9_9 = 0.0
# X_0_0 = 0.0
# X_0_1 = 0.0
# X_0_10 = 0.0
# X_0_11 = 0.0
# X_0_12 = 0.0
# X_0_13 = 0.0
# X_0_14 = 0.0
# X_0_15 = 0.0
# X_0_16 = 0.0
# X_0_17 = 0.0
# X_0_18 = 0.0
# X_0_19 = 0.0
# X_0_2 = 0.0
# X_0_20 = 0.0
# X_0_21 = 0.0
# X_0_22 = 0.0
# X_0_23 = 0.0
# X_0_24 = 0.0
# X_0_25 = 1.0
# X_0_26 = 0.0
# X_0_27 = 0.0
# X_0_28 = 0.0
# X_0_29 = 0.0
# X_0_3 = 0.0
# X_0_4 = 0.0
# X_0_5 = 0.0
# X_0_6 = 0.0
# X_0_7 = 0.0
# X_0_8 = 0.0
# X_0_9 = 0.0
# X_10_0 = 0.0
# X_10_1 = 0.0
# X_10_10 = 0.0
# X_8_20 = 0.0
# X_8_21 = 0.0
# X_8_22 = 0.0
# X_8_23 = 0.0
# X_8_24 = 0.0
# X_8_25 = 0.0
# X_8_26 = 0.0
# X_8_27 = 0.0
# X_8_28 = 0.0
# X_8_29 = 0.0
# X_8_3 = 0.0
# X_8_4 = 0.0
# X_8_5 = 0.0
# X_8_6 = 0.0
# X_8_7 = 0.0
# X_8_8 = 0.0
# X_8_9 = 0.0
# X_9_0 = 0.0
# X_9_1 = 0.0
# X_9_10 = 0.0
# X_9_11 = 0.0
# X_9_12 = 0.0
# X_9_13 = 0.0
# X_9_14 = 0.0
# X_9_15 = 0.0
# X_9_16 = 0.0
# X_9_17 = 0.0
# X_9_18 = 0.0
# X_9_19 = 0.0
# X_9_2 = 0.0
# X_9_20 = 0.0
# X_9_21 = 0.0
# X_9_22 = 0.0
# X_9_23 = 0.0
# X_9_24 = 0.0
# X_9_25 = 0.0
# X_9_26 = 0.0
# X_9_27 = 0.0
# X_9_28 = 0.0
# X_9_29 = 0.0
# X_9_3 = 0.0
# X_9_4 = 0.0
# X_9_5 = 1.0
# X_9_6 = 0.0
# X_9_7 = 0.0
# X_9_8 = 0.0
# X_9_9 = 0.0
# objective_function = 29858017.09125964

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Extract edges from the solution
edges = []
for var in problem.variables():
    if var.name.startswith("X_") and var.varValue == 1:
        # Parse indices (e.g., "X_0_25" -> (0, 25))
        parts = var.name.split("_")
        i = int(parts[1])
        j = int(parts[2])
        edges.append((i, j))

# Create a directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(V)

# Add edges
G.add_edges_from(edges)

# Extract node coordinates from NodesCord (convert np.int64 to float)
pos = {node: (float(NodesCord[node][0]), float(NodesCord[node][1])) for node in NodesCord}

# Draw the graph
plt.figure(figsize=(12, 12))
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=500,
        edge_color='gray', arrows=True, arrowsize=20)
plt.title("Graphe initial")
plt.show()

# %% [markdown]
# ## Scénario 2 (Pas optimal)
# Modification du graphe initial pour assurer le fonctionnement du réseau en cas de panne sur une arête (on cherche à construire un graphe 2-connexe)

# %%
import networkx as nx
import random

# --- 0. Graphe de départ orienté (issu de l'optimisation)
# On suppose que G est déjà défini comme un nx.DiGraph()

# --- 1. Convertir en non orienté pour l’analyse
G_undirected = G.to_undirected()
G_base = G_undirected.copy()     # Arbre initial
G_modified = G_undirected.copy() # Copie à modifier (arêtes de secours seront ajoutées ici)

# --- 2. Initialiser liste des arêtes de secours
backup_edges = []
base_edges_set = set(G_base.edges())  # Pour éviter les doublons avec l’arbre initial

# --- 3. Boucle sur toutes les arêtes critiques (toutes les arêtes d’un arbre)
for A, B in list(G_base.edges()):

    # --- Supprimer temporairement l’arête du graphe EN COURS de construction
    if G_modified.has_edge(A, B):
        G_modified.remove_edge(A, B)

    # --- Vérifier la connectivité entre A et B
    if nx.has_path(G_modified, A, B):
        print(f"[INFO] ✅ Un chemin alternatif existe déjà entre {A} et {B}")
        # On remet l’arête (A, B) après la vérif
        G_modified.add_edge(A, B)
        continue

    # --- Sinon : construire une arête de secours

    # Définir les ensembles de candidats (voisins directs + le nœud lui-même)
    liste_A = set(G_base.neighbors(A))
    liste_A.add(A)
    liste_B = set(G_base.neighbors(B))
    liste_B.add(B)

    candidates_A = list(liste_A )
    candidates_B = list(liste_B )

    # Générer toutes les paires valides
    all_possible_pairs = [
        (u, v) for u in candidates_A for v in candidates_B
        if u != v and (u, v) not in base_edges_set and (v, u) not in base_edges_set
    ]

    valid_pairs = [(u, v) for (u, v) in all_possible_pairs if (u, v) != (A, B) and (u, v) != (B, A)]



    if valid_pairs :
        u, v = random.choice(valid_pairs)
        G_modified.add_edge(u, v, backup=True)
        backup_edges.append((u, v))
        print(f"[INFO] ➕ Arête de secours ajoutée entre {u} et {v}")
    else:
        print(f"[WARN] ⚠️ Aucune arête de secours valide trouvée pour la coupure ({A}, {B})")

    # Remettre l’arête de base (A, B)
    G_modified.add_edge(A, B)

# --- Résumé final
print("\n=== Arêtes de secours finales ===")
print(backup_edges)
# Out:
# [INFO] ➕ Arête de secours ajoutée entre 6 et 27
# [INFO] ✅ Un chemin alternatif existe déjà entre 0 et 6
# [INFO] ➕ Arête de secours ajoutée entre 20 et 16
# [INFO] ✅ Un chemin alternatif existe déjà entre 1 et 20
# [INFO] ➕ Arête de secours ajoutée entre 20 et 19
# [INFO] ➕ Arête de secours ajoutée entre 7 et 22
# [INFO] ✅ Un chemin alternatif existe déjà entre 2 et 7
# [INFO] ➕ Arête de secours ajoutée entre 19 et 14
# [INFO] ✅ Un chemin alternatif existe déjà entre 3 et 19
# [INFO] ➕ Arête de secours ajoutée entre 3 et 10
# [INFO] ➕ Arête de secours ajoutée entre 21 et 5
# [INFO] ✅ Un chemin alternatif existe déjà entre 4 et 21
# [INFO] ➕ Arête de secours ajoutée entre 9 et 13
# [INFO] ✅ Un chemin alternatif existe déjà entre 5 et 9
# [INFO] ➕ Arête de secours ajoutée entre 0 et 19
# [INFO] ➕ Arête de secours ajoutée entre 2 et 10
# [INFO] ✅ Un chemin alternatif existe déjà entre 8 et 10
# [INFO] ➕ Arête de secours ajoutée entre 12 et 29
# [INFO] ✅ Un chemin alternatif existe déjà entre 11 et 12
# [INFO] ➕ Arête de secours ajoutée entre 11 et 17
# [INFO] ➕ Arête de secours ajoutée entre 13 et 26
# [INFO] ✅ Un chemin alternatif existe déjà entre 13 et 28
# [INFO] ➕ Arête de secours ajoutée entre 15 et 23
# [INFO] ➕ Arête de secours ajoutée entre 17 et 1
# [INFO] ✅ Un chemin alternatif existe déjà entre 18 et 19
# [INFO] ✅ Un chemin alternatif existe déjà entre 19 et 21
# [INFO] ➕ Arête de secours ajoutée entre 2 et 24
# [INFO] ✅ Un chemin alternatif existe déjà entre 23 et 26
# [INFO] ✅ Un chemin alternatif existe déjà entre 25 et 27
#
# === Arêtes de secours finales ===
# [(6, 27), (20, 16), (20, 19), (7, 22), (19, 14), (3, 10), (21, 5), (9, 13), (0, 19), (2, 10), (12, 29), (11, 17), (13, 26), (15, 23), (17, 1), (2, 24)]

# %%
import matplotlib.pyplot as plt

# --- 1. Position des nœuds depuis NodesCord (à adapter si tu as la vraie variable)
# Exemple : pos = {0: (1.0, 2.0), 1: (3.5, 4.0), ...}
pos = {node: (float(NodesCord[node][0]), float(NodesCord[node][1])) for node in NodesCord}

# --- 2. Séparer les arêtes de base et les arêtes de secours
edges_base = G.edges()
edges_backup = []

for u, v in G_modified.edges():
    if (u, v) in backup_edges or (v, u) in backup_edges:
        edges_backup.append((u, v))


# --- 3. Affichage
plt.figure(figsize=(12, 12))

# Dessiner les nœuds et labels
nx.draw_networkx_nodes(G_modified, pos, node_color='skyblue', node_size=500)
nx.draw_networkx_labels(G_modified, pos)

# Arêtes de base : gris
nx.draw_networkx_edges(G_modified, pos,
    edgelist=edges_base,
    edge_color='gray',
    width=2,
    arrows=True,
    arrowsize=20
)

# Arêtes de secours : rouge pointillé
nx.draw_networkx_edges(G_modified, pos,
    edgelist=edges_backup,
    edge_color='red',
    style='dashed',
    width=2,
    arrows=True,
    arrowsize=20
)

plt.title("Réseau avec arêtes de base (gris) et arêtes de secours (rouge pointillé)")
plt.axis('off')
plt.show()

# %%
import networkx as nx
print(f"Is G_modified 2_connexe: {nx.is_k_edge_connected(G_modified, 2)}")
print(f"Le nombre d'aretes de secours ajoutées: {len(backup_edges)}")
# Out:
# Is G_modified 2_connexe: True
# Le nombre d'aretes de secours ajoutées: 16

# %% [markdown]
# ## Scénario 2 (k-augmentation)
# On cherche à modifier le graphe initial pour qu'il soit 2-connexe en utilisant la fonction k_edge_augmentation de la librairie networkx

# %%
import networkx as nx
import random

# --- 0. Graphe de départ orienté (issu de l'optimisation)
# On suppose que G est déjà défini comme un nx.DiGraph()

# --- 1. Convertir en non orienté pour l’analyse
G_undirected = G.to_undirected()
G_base2 = G_undirected.copy()     # Arbre initial
G_modified2 = G_undirected.copy() # Copie à modifier (arêtes de secours seront ajoutées ici)

edges_backup = list(nx.k_edge_augmentation(G_modified2, 2))
edges_base = G.edges()

plt.figure(figsize=(12, 12))
# Dessiner les nœuds et labels
nx.draw_networkx_nodes(G_modified, pos, node_color='skyblue', node_size=500)
nx.draw_networkx_labels(G_modified, pos)

# Arêtes de base : gris
nx.draw_networkx_edges(G_modified2, pos,
    edgelist=edges_base,
    edge_color='gray',
    width=2,
    arrows=True,
    arrowsize=20
)

# Arêtes de secours : rouge pointillé
nx.draw_networkx_edges(G_modified2, pos,
    edgelist=edges_backup,
    edge_color='red',
    style='dashed',
    width=2,
    arrows=True,
    arrowsize=20
)
plt.title("Graphe avec networkx augmentation")
plt.show()
plt.show()

# %%
import networkx as nx
for e in edges_backup:
    u,v=e
    G_modified2.add_edge(u,v)
print(f"Is G_modified2  2_connexe: {nx.is_k_edge_connected(G_modified2, 2)}")
print(f"Le nombre d'arêtes de secours ajoutées: {len(edges_backup)}")
# Out:
# Is G_modified2  2_connexe: True
# Le nombre d'arêtes de secours ajoutées: 3
